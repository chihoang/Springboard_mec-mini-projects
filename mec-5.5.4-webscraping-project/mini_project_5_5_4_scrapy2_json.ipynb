# %% [markdown]
# <a href="https://colab.research.google.com/github/chihoang/Springboard_mec-mini-projects/blob/main/mini_project_5_5_4_scrapy2_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import scrapy

# %%
# Settings for notebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Show Python version
import platform
platform.python_version()

from IPython.display import HTML
import pandas as pd
import json

# %%
## import scrapy ##
try:
    import scrapy
except:
    # !pip install scrapy
    import scrapy
from scrapy.crawler import CrawlerProcess
# from scrapy.crawler import CrawlerRunner

# !pip install crochet
# from crochet import setup, wait_for
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 271 kB 22.1 MB/s
# ...
#      |████████████████████████████████| 93 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 48.7 MB/s
# ...
#      |████████████████████████████████| 254 kB 54.7 MB/s
# ...
#      |████████████████████████████████| 57 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 33.5 MB/s
# ...
#      |████████████████████████████████| 74 kB 3.2 MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.6-py3-none-any.whl size=11959 sha256=98c21cd2bed17167be3eb406b95a141f2cb764cf3fd419e1e2e3fd33967437c1
#   Stored in directory: /root/.cache/pip/wheels/c9/d6/6a/de198d890277cde60ca3dbebe7ae592d3b381c7d9bb2455f4d
# Successfully built PyDispatcher
# ...

# %%
# set up new Scrapy project
# !scrapy startproject scrapy_mini_project
# %rm -rf scrapy_mini_project

# %%
# ### zip to download
# !zip -r /content/scrapy_mini_project.zip /content/scrapy_mini_project

# %% [markdown]
# # Define a more complicated spider that saves scraped data to json files

# %%
## define the pipeline to use next 

class JsonWriterPipeline(object):

    def open_spider(self, spider):
        self.file = open('quoteresult.jl', 'w')

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %%
## can scrape first two pages 
import logging

class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = [
        'http://quotes.toscrape.com/page/1/',
        'http://quotes.toscrape.com/page/2/', 
    ]

    custom_settings = {
        # 'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1}, # Used for pipeline 1
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': 'quoteresult.json'                        # Used for pipeline 2
    }
    
    def parse(self, response):
        for quote in response.css('div.quote'):
            yield {
                'text': quote.css('span.text::text').extract_first(),
                'author': quote.css('span small::text').extract_first(),
                'tags': quote.css('div.tags a.tag::text').extract(),
            }

# %% [markdown]
# # Start the crawler

# %%
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})
process.crawl(QuotesSpider)
process.start()

# process = CrawlerRunner()
# process.crawl(QuotesSpider)
# Out:
# INFO:scrapy.utils.log:Scrapy 2.7.1 started (bot: scrapybot)
# 2022-11-25 19:15:09 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: scrapybot)
# INFO:scrapy.utils.log:Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.0.1, Twisted 22.10.0, Python 3.7.15 (default, Oct 12 2022, 19:14:55) - [GCC 7.5.0], pyOpenSSL 22.1.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 38.0.3, Platform Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# 2022-11-25 19:15:09 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.0.1, Twisted 22.10.0, Python 3.7.15 (default, Oct 12 2022, 19:14:55) - [GCC 7.5.0], pyOpenSSL 22.1.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 38.0.3, Platform Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# INFO:scrapy.crawler:Overridden settings:
# {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2022-11-25 19:15:09 [scrapy.crawler] INFO: Overridden settings:
# ...

# %% [markdown]
# # Check the result files

# %%
dfjson = pd.read_json('quoteresult.json')
dfjson
# Out:
#                                                  text               author  \
# 0   “The world as we have created it is a process ...      Albert Einstein
# 1   “It is our choices, Harry, that show what we t...         J.K. Rowling
# 2   “There are only two ways to live your life. On...      Albert Einstein
# 3   “This life is what you make it. No matter what...       Marilyn Monroe
# 4   “It takes a great deal of bravery to stand up ...         J.K. Rowling
# 5   “The person, be it gentleman or lady, who has ...          Jane Austen
# 6   “Imperfection is beauty, madness is genius and...       Marilyn Monroe
# 7   “If you can't explain it to a six year old, yo...      Albert Einstein
# 8   “You may not be her first, her last, or her on...           Bob Marley
# 9   “Try not to become a man of success. Rather be...      Albert Einstein
# 10  “It is better to be hated for what you are tha...           André Gide
# ...

# %%
dfjson.tail()
# Out:
#                                                  text               author  \
# 15  “A woman is like a tea bag; you never know how...    Eleanor Roosevelt
# 16  “It is not a lack of love, but a lack of frien...  Friedrich Nietzsche
# 17  “Good friends, good books, and a sleepy consci...           Mark Twain
# 18  “A day without sunshine is like, you know, nig...         Steve Martin
# 19  “Life is what happens to us while we are makin...       Allen Saunders
#
#                                                  tags
# 15                  [misattributed-eleanor-roosevelt]
# 16  [friendship, lack-of-friendship, lack-of-love,...
# 17    [books, contentment, friends, friendship, life]
# 18                           [humor, obvious, simile]
# 19  [fate, life, misattributed-john-lennon, planni...

# %%
dfjson.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    20 non-null     object
#  1   author  20 non-null     object
#  2   tags    20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes
